# %%
import pandas as pd

# %%
direcciones = pd.read_csv('data/direcciones.csv', sep=';',encoding='latin-1')
# Out:
# C:\Users\Gomi\AppData\Local\Temp\ipykernel_11180\3895164154.py:1: DtypeWarning: Columns (16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   direcciones = pd.read_csv('data/direcciones.csv', sep=';',encoding='latin-1')

# %%
direcciones
# Out:
#         Codigo de numero  Codigo de via           Clase de la via  \
# 0               31031089       31001337  AUTOVIA
# 1               31031088       31001337  AUTOVIA
# 2               31031091       31001337  AUTOVIA
# 3               31031090       31001337  AUTOVIA
# 4               31031093       31001337  AUTOVIA
# ...                  ...            ...                       ...
# 210358          20045135            725  PASEO
# 210359          20045138            725  PASEO
# 210360          20045141            725  PASEO
# 210361          20045144            725  PASEO
# 210362          20045147            725  PASEO
#
#        Partï¿½cula de la vï¿½a  \
# 0
# 1
# 2
# 3
# 4
# ...                        ...
# 210358                  DEL
# 210359                  DEL
# 210360                  DEL
# 210361                  DEL
# 210362                  DEL
#
#                                       Nombre de la vï¿½a  \
# 0       A-1
# 1       A-1
# 2       A-1
# 3       A-1
# ...

# %%
direcciones.dtypes
# Out:
# Codigo de v�a tratado                     int64
# Literal completo del vial tratado        object
# Clase de la via tratado                  object
# Particula de la via tratado              object
# Nombre de la via tratado                 object
# Codigo de via que cruza o enlaza          int64
# Literal completo del vial que cruza      object
# Clase de la via que cruza                object
# Particula de la via que cruza            object
# Nombre de la via que cruza               object
# Coordenada X (Guia Urbana) cm (cruce)     int64
# Coordenada Y (Guia Urbana) cm (cruce)     int64
# Longitud en S R  WGS84 (cruce)           object
# Latitud en S R  WGS84 (cruce)            object
# dtype: object
